# %% [markdown]
# ### 2019-10-02: Homework 2: total 100 points for Pandas and Matplotlib
# ### Submission due date by the end of Oct. 9th, 2019.
# ### Total 100 points.

# %% [raw]
# Pandas Homework: 9 questions, total 50 points.

# %% [raw]
# 1. Given data = [1,2,3,4,5,6,7,8,9,5,3], create a Pandas Series, then calculate the mean and standard deviation of the Series and print the outputs.
#  (3 points)

# %%
import pandas as pd
ser = pd.Series([1, 2, 3, 4, 5, 6, 7, 8, 9, 5, 3])
res_mean = ser.mean(skipna = True)
print("The Mean of the Pandas Series is :")
print(res_mean)
res_std = ser.std(skipna = True)
print("The Standard Deviation of the Pandas Series is :")
print(res_std)
# Out:
# The Mean of the Pandas Series is :
# 4.818181818181818
# The Standard Deviation of the Pandas Series is :
# 2.522624895547565

# %% [raw]
# 2. There are two Pandas Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 9]. Compare the elements of the two Pandas Series. Expected outputs are to print two series comparing with "equal", "greater than", and "less than". (4 points)

# %%
ser1 = pd.Series([2, 4, 6, 8, 10])
ser2 = pd.Series([1, 3, 5, 7, 9])
equals = ser1.equals(other = ser2)
print("Are the series equal :")
print(equals)
print("Alternative way :")
print("Are the series equal :\n",ser1 ==ser2)
greater_than = ser1.ge(other = ser2)
print("Are the 1st series values greater than 2nd series ones :")
print(greater_than)
lesser_than = ser1.le(other = ser2)
print("Are the 1st series values lesser than 2nd series ones :")
print(lesser_than)
# Out:
# Are the series equal :
# False
# Alternative way :
# Are the series equal :
#  0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Are the 1st series values greater than 2nd series ones :
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool
# Are the 1st series values lesser than 2nd series ones :
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [raw]
# 3. NumPy array: d1 = [10, 20, 30, 40, 50];  dictionary: d2 = {'a': 100, 'b': 200, 'c':300, 'd':400, 'e':800}
# Convert the NumPy array and the dictionary to Pandas Series, respectively. (2 points)

# %%
import numpy as np
d1 = np.array([10, 20, 30, 40, 50])
num_series = pd.Series(d1)
print("The numpy array to series is :")
print(num_series)
d2 = {'a': 100, 'b': 200, 'c':300, 'd':400, 'e':800}
dict_series = pd.Series(d2)
print("The dictionary to series is :")
print(dict_series)
# Out:
# The numpy array to series is :
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32
# The dictionary to series is :
# a    100
# b    200
# c    300
# d    400
# e    800
# dtype: int64

# %% [raw]
# 4. Contruct a DataFrame as the sameple data here. Use "iloc" to convert the first column of a DataFrame as a Series. (4 points)
# Sample data:
#     col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11

# %%
dataframe = pd.DataFrame({'col1': [1, 2, 3, 4, 7, 11], 'col2': [4, 5, 6, 9, 5, 0], 'col3': [7, 5, 8, 12, 1, 11]})
print("The dataframe is :")
print(dataframe)
dataframe_series = dataframe.iloc[:,0]
print("The first column of dataframe to series :")
print(dataframe_series)
# Out:
# The dataframe is :
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11
# The first column of dataframe to series :
# 0     1
# 1     2
# 2     3
# 3     4
# 4     7
# 5    11
# Name: col1, dtype: int64

# %% [raw]
# 5. Create a DataFrame with multiple indice, the result should be the following: here, "random" means any integer random number for books. [7 point]
#
#                        Bob     Tom
#  1st          2nd
# fiction       one     random  random
#               two     random  random
# non-fiction   one     random  random
#               two     random  random
# sci-fi        one     random  random
#               two     random  random
# chapter       one     random  random
#               two     random  random

# %%
import random
genre = [('fiction', 'one'), ('fiction', 'two'),
         ('non-fiction', 'one'), ('non-fiction', 'two'),
         ('sci-fi', 'one'), ('sci-fi', 'two'),
         ('chapter','one'), ('chapter','two')]
bob = random.sample(range(1, 20), 8)
tom = random.sample(range(10, 30), 8)

ser_genre1 = pd.Series(bob, index=genre)
ser_genre2 = pd.Series(tom, index=genre)

#creating  Multi-index from genre
index = pd.MultiIndex.from_tuples(genre)
index

genre2=pd.DataFrame({'Bob':ser_genre1, 'Tom':ser_genre2},index)
genre2.index.names=['1st','2nd']
print("The resultant dataframe is :")
genre2
# Out:
# The resultant dataframe is :
#                  Bob  Tom
# 1st         2nd
# fiction     one    2   20
#             two    9   28
# non-fiction one   13   17
#             two    1   23
# sci-fi      one   19   15
#             two   12   19
# chapter     one   10   10
#             two   17   21

# %% [raw]
# 6. Write a Pandas program to replace all the NaN values with Zero's in a column of a dataframe. [5 points].
# Sample data is a dataset for an exam:
# Original DataFrame
# attempts name qualify score
# 0 1 Anastasia yes 12.5
# 1 3 Dima no 9.0
# 2 2 Katherine yes 16.5
# 3 3 James no NaN
# 4 2 Emily no 9.0
# 5 3 Michael yes 20.0
# 6 1 Matthew yes 14.5
# 7 1 Laura no NaN
# 8 2 Kevin no 8.0
# 9 1 Jonas yes 19.0
# 1) Construct a DataFrame and the column in the order as name, score, attempts, qualify
# 2) New DataFrame replacing all NaN with 0.

# %%
import pandas as pd
import numpy as np
dataframe = pd.DataFrame({'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael','Matthew','Laura','Kevin','Jonas'],  'score': [12.5, 9.0, 16.5, np.nan, 9.0, 20.0, 14.5, np.nan, 8.0, 19.0],'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1], 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes','no', 'no', 'yes']})
print('1. DataFrame and the column in the order as name, score, attempts, qualify is as follows :')
dataframe
# Out:
# 1. DataFrame and the column in the order as name, score, attempts, qualify is as follows :
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
print('2. New DataFrame without NaNs :')
dataframe.fillna(0)
# Out:
# 2. New DataFrame without NaNs :
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    0.0         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    0.0         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %% [raw]
# 7. Sort a given Series; add some data ['500', 'php'] to an existing Series; [5 points]
# Original Data Series:
# 0       100
# 1       200
# 2    python
# 3    300.12
# 4       400

# %%
ser1 = pd.Series(['100', '200', 'python', '300.12', '400'])
ser2 = pd.Series(['500', 'php'], index=[5, 6])
print("Sorting the given series :")
ser_original = ser1.sort_values()
print(ser_original)

print("Adding new data to series :")
ser = ser_original.append(ser2)
print(ser)
# Out:
# Sorting the given series :
# 0       100
# 1       200
# 3    300.12
# 4       400
# 2    python
# dtype: object
# Adding new data to series :
# 0       100
# 1       200
# 3    300.12
# 4       400
# 2    python
# 5       500
# 6       php
# dtype: object

# %% [raw]
# 8. Count number of columns of the DataFrame; select all columns, except one given column 'col3'; remove first 3 rows of the DataFrame; remove last 3 rows of the DataFrame. [10 points]
# Sample DataFrame:
#     col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11

# %%
dataframe = pd.DataFrame({'col1': [1, 2, 3, 4, 7, 11], 'col2': [4, 5, 6, 9, 5, 0], 'col3': [7, 5, 8, 12, 1, 11]})
print("Select all columns :")
dataframe
# Out:
# Select all columns :
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11

# %%
print('Count of number of columns :')
print(len(dataframe.columns))
# Out:
# Count of number of columns :
# 3

# %%
print('All columns except column-3 :')
print('Method-1 :')
dataframe1 = dataframe.loc[:, dataframe.columns != 'col3']
dataframe1
# Out:
# All columns except column-3 :
# Method-1 :
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
# 3     4     9
# 4     7     5
# 5    11     0

# %%
print('Method-2 :')
new = dataframe[['col1','col2']]
new
# Out:
# Method-2 :
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
# 3     4     9
# 4     7     5
# 5    11     0

# %%
print("Method-1")
print('Remove first 3 rows of DataFrame :')
first = dataframe.drop(dataframe.index[:3])
first
# Out:
# Method-1
# Remove first 3 rows of DataFrame :
#    col1  col2  col3
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11

# %%
print("Method-2")
first1 = dataframe.drop(dataframe.index[[0,1,2]])
first1
# Out:
# Method-2
#    col1  col2  col3
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11

# %%
print("Method-1")
print('Remove last 3 rows of the DataFrame :')
last = dataframe.drop(dataframe.index[3:])
last
# Out:
# Method-1
# Remove last 3 rows of the DataFrame :
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8

# %%
print("Method-2")
last1 = dataframe.drop(dataframe.index[[3,4,5]])
last1
# Out:
# Method-2
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8

# %% [raw]
# 9. [10 points]:
# 1. read data from movies.csv file to Pandas
# 2. get the information of the DataFrame (movies.csv file) including data types and memory usage.
# 3. count the number of rows and columns of the DataFrame
# 4. get the details of fifth movie of the DataFrame.
# 5. display the movies (title, runtime)longer than 30 minutes and shorter than 360 minutes.

# %%
import pandas as pd
print('1. read data from movies.csv file to Pandas')
data = pd.read_csv('C:/Users/mohar/Downloads/movies.csv')
data
# Out:
# 1. read data from movies.csv file to Pandas
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# ...

# %%
print('2. get the information of the DataFrame (movies.csv file) including data types and memory usage.')
data.info()
# Out:
# 2. get the information of the DataFrame (movies.csv file) including data types and memory usage.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 24 columns):
# adult                    50 non-null bool
# belongs_to_collection    10 non-null object
# budget                   50 non-null int64
# genres                   50 non-null object
# homepage                 5 non-null object
# id                       50 non-null int64
# imdb_id                  50 non-null object
# original_language        50 non-null object
# original_title           50 non-null object
# overview                 49 non-null object
# popularity               50 non-null float64
# poster_path              50 non-null object
# production_companies     50 non-null object
# production_countries     50 non-null object
# release_date             50 non-null object
# revenue                  50 non-null int64
# runtime                  50 non-null float64
# ...

# %%
print('3. count the number of rows and columns of the DataFrame')
total_rows=len(data.axes[0])
total_cols=len(data.axes[1])
print("Number of Rows: ",total_rows)
print("Number of Columns: ",total_cols)
# Out:
# 3. count the number of rows and columns of the DataFrame
# Number of Rows:  50
# Number of Columns:  24

# %%
print('4. get the details of fifth movie of the DataFrame')
print("Method-1")
result = data.iloc[4]
result
# Out:
# 4. get the details of fifth movie of the DataFrame
# Method-1
# adult                                                                False
# belongs_to_collection    {'id': 96871, 'name': 'Father of the Bride Col...
# budget                                                                   0
# genres                                      [{'id': 35, 'name': 'Comedy'}]
# homepage                                                               NaN
# id                                                                   11862
# imdb_id                                                          tt0113041
# original_language                                                       en
# original_title                                 Father of the Bride Part II
# overview                 Just when George Banks has recovered from his ...
# popularity                                                         8.38752
# poster_path                               /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...

# %%
print("Method-2")
data[4:5]
# Out:
# Method-2
#    adult                              belongs_to_collection  budget  \
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...       0
#
#                            genres homepage     id    imdb_id  \
# 4  [{'id': 35, 'name': 'Comedy'}]      NaN  11862  tt0113041
#
#   original_language               original_title  \
# 4                en  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#     revenue runtime                          spoken_languages    status  \
# 4  76578911   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 4  Father of the Bride Part II  False          5.7        173
#
# [1 rows x 24 columns]

# %%
print('5. display the movies (title, runtime)longer than 30 minutes and shorter than 360 minutes')
small_df = data[['title', 'runtime']]
result = small_df[(small_df['runtime'] > 30) & (small_df['runtime'] < 360)]
result
# Out:
# 5. display the movies (title, runtime)longer than 30 minutes and shorter than 360 minutes
#                              title  runtime
# 0                        Toy Story     81.0
# 1                          Jumanji    104.0
# 2                 Grumpier Old Men    101.0
# 3                Waiting to Exhale    127.0
# 4      Father of the Bride Part II    106.0
# 5                             Heat    170.0
# 6                          Sabrina    127.0
# 7                     Tom and Huck     97.0
# 8                     Sudden Death    106.0
# 9                        GoldenEye    130.0
# 10          The American President    106.0
# 11     Dracula: Dead and Loving It     88.0
# 12                           Balto     78.0
# 13                           Nixon    192.0
# 14                Cutthroat Island    119.0
# 15                          Casino    178.0
# 16           Sense and Sensibility    136.0
# 17                      Four Rooms     98.0
# ...

# %% [raw]
# Matplotlib: 5 questions, total 50 points.

# %% [raw]
# 1. [3 points]: plot several lines with different format styles in one command using arrays.
# Sampled time at 200ms intervals
# t = np.arange(0., 5., 0.2)
# green dashes, blue squares and red triangles to plot t, t**2, t**3.

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'g--', t, t**2, 'bs', t, t**3, 'r^')
plt.show()

# %% [raw]
# 2. [7 points]: plot line1 and line2 with different styles
# # line 1 points
# x1 = [10,20,30]
# y1 = [20,40,10]
# # line 2 points
# x2 = [10,20,30]
# y2 = [40,10,30]
# Set the x and y axes labels as 'x' and 'y';  # 2point
# Plot lines and/or markers to the Axes: blue,red; dotted, dashed;   # 3point
# Set a title: "Plot with two or more lines with different styles";  # 1point
# show a legend on the plot as 'line1-dotted', 'line2-dashed'.   # 1point

# %%
import matplotlib.pyplot as plt

x1 = [10,20,30]
y1 = [20,40,10]

x2 = [10,20,30]
y2 = [40,10,30]

plt.xlabel('x - axis')


plt.ylabel('y - axis')

plt.plot(x1,y1, color='blue', linewidth = 3,  label = 'line1-dotted',linestyle='dotted')
plt.plot(x2,y2, color='red', linewidth = 5,  label = 'line2-dashed', linestyle='dashed')

plt.title("plot line1 and line2 with different styles")

plt.legend()

plt.show()

# %% [raw]
# 3. [5 points]: draw a scatter plot with empty circles taking a 50-point random distribution in X and Y; set X and Y as x- and y- axes lables;
#   any color for face and edge, and plotted against each other.

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x = np.random.randn(50) 
y = np.random.randn(50)
plt.scatter(x, y, s=70, facecolors='none', edgecolors='g')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [raw]
# 4. [5 points]:  create bar plot from a DataFrame.
# Sample DataFrame:
#   a b c d e
# 2 4,8,5,7,6
# 4 2,3,4,2,6
# 6 4,7,4,7,8
# 8 2,6,4,8,6
# 10 2,4,3,3,2

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np

a=np.array([[4,8,5,7,6],[2,3,4,2,6],[4,7,4,7,8],[2,6,4,8,6],[2,4,3,3,2]])
df=DataFrame(a, columns=['a','b','c','d','e'], index=[2,4,6,8,10])

df.plot(kind='bar')

plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.show()

# %% [raw]
# 5. [30 points]:
# The following dataset for average monthly precipitation. You will create and customize a plot.
# Month    Precipitation (inches)
# Jan      0.70
# Feb      0.75
# Mar      1.85
# Apr      2.93
# May      3.05
# June     2.02
# July     1.93
# Aug      1.62
# Sept     1.84
# Oct      1.31
# Nov      1.39
# Dec      0.84

# %% [raw]
# 5.1 [10 points]: Begin by creating a plot using the default styles provided by matplotlib.pyplot. You will use months along the x-axis and precip along the y-axis; and set plot size [8,8] for the plot:

# %%
import matplotlib.pyplot as plt

jan = 0.70
feb = 0.75
mar = 1.85
apr = 2.93
may = 3.05
june = 2.02
july = 1.93
aug = 1.62
sept = 1.84
oct = 1.31
nov = 1.39
dec = 0.84

precip = [jan, feb, mar, apr, may, june, july, aug, sept, oct, nov, dec] 

months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

plt.rcParams["figure.figsize"] = (8, 8)

fig, ax = plt.subplots()

ax.plot(months, precip);

# %% [raw]
# 5.2 [10 points]: Add Title and Axis Labels
# set plot title as "Average Monthly Precipitation";
# add labels to the axes: x label as "Month", y label as "Precipitation (inches)"

# %%
plt.rcParams["figure.figsize"] = (8,8)

plt.rcParams['axes.titlesize'] = 20

fig,ax = plt.subplots()

ax.plot(months,precip)

ax.set(title="Average Monthly Precipitation")
ax.set(xlabel="Month", ylabel="Precipitation (inches)");

# %% [raw]
# 5.3 [10 points]: Change Plot Type
# You can turn your plot into a bar plot;
# also assign a fill color using "green".

# %%
plt.rcParams["figure.figsize"] = (8, 8)

fig, ax = plt.subplots()

ax.bar(months, precip, color="green")

ax.set(title="Average Monthly Precipitation")

ax.set(xlabel="Month", ylabel="Precipitation (mm)");
